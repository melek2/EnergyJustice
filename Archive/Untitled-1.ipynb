# %%
import pandas as pd
# from arcgis.features import FeatureLayer
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import requests
import pandas as pd

# Base URL for the REST API
base_url = "https://services2.arcgis.com/mJaJSax0KPHoCNB6/arcgis/rest/services/DRPComplianceRelProd/FeatureServer/0/query"

# Define query parameters
params = {
    "where": "1=1",  # Select all records
    "outFields": "*",  # Retrieve all fields
    "f": "json"  # Format response as JSON
}

# %%
response = requests.get(base_url, params=params)

# %%
if response.status_code == 200:
    data = response.json()
    
    # Extract features from the response
    features = data.get("features", [])
    
    # Convert to DataFrame for easier handling
    records = [feature["attributes"] for feature in features]
    df = pd.DataFrame(records)
    
    print("Data Retrieved:")
    print(df.head())
else:
    print(f"Error: {response.status_code}")
# Out:
# Data Retrieved:
#    OBJECTID SubstationName SubstationID  NUMBANKS REDACTED UNGROUNDEDBANKS  \
# 0         1         ZAMORA        06319         2       No            None
# 1         2     EAST GRAND        02257         5      Yes            None
# 2         3         CORRAL        16299         2       No             1,1
# 3         4     STOCKTON A        16237         5      Yes            None
# 4         5    MORGAN HILL        08324         3       No            None
#
#      Division  Existing_DG  Queued_DG  Total_DG  Last_Update_On_Map  \
# 0  Sacramento         4750         40      4790       1730909047000
# 1   Peninsula        18900       1490     20390       1730909049000
# 2    Stockton        23120        440     23560       1730909049000
# 3    Stockton        21810       1020     22830       1730909049000
# 4    San Jose        51250      16000     67250       1730909049000
#
#    Voltage_kV  Publish
# 0        12.0        1
# 1         4.0        1
# 2        12.0        1
# 3         4.0        1
# 4        12.0        1

# %%
import requests
import pandas as pd

# Base URL for the REST API (Layer 23)
base_url = "https://services2.arcgis.com/mJaJSax0KPHoCNB6/ArcGIS/rest/services/DRPComplianceRelProd/FeatureServer/23/query"

# Define query parameters
params = {
    "where": "1=1",  # Select all records
    "outFields": "*",  # Retrieve all fields
    "returnGeometry": "true",  # Include geometry (longitude/latitude)
    "f": "json"  # Format response as JSON
}

# Send GET request to query the layer
response = requests.get(base_url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse JSON response
    data = response.json()
    
    # Extract features from the response
    features = data.get("features", [])
    
    # Convert to DataFrame for easier analysis
    records = [feature["attributes"] for feature in features]
    df = pd.DataFrame(records)
    
    print("Data Retrieved:")
    print(df.head())  # Display the first few rows of data

    # Optional: Save data to CSV
    # df.to_csv("layer_23_data.csv", index=False)
    print("Data saved to 'layer_23_data.csv'")
else:
    print(f"Error: {response.status_code}")
    print("Response Text:", response.text)
# Out:
# Data Retrieved:
#    OBJECTID  FeederID MonthHour   Low  High  Division  Publish  \
# 0         1  12011113     01_00  1720  2121  East Bay        1
# 1         2  12011113     01_01  1594  1983  East Bay        1
# 2         3  12011113     01_02  1533  1877  East Bay        1
# 3         4  12011113     01_03  1489  1823  East Bay        1
# 4         5  12011113     01_04  1442  1788  East Bay        1
#
#    Last_Update_On_Map
# 0       1730907190000
# 1       1730907190000
# 2       1730907190000
# 3       1730907190000
# 4       1730907190000
# Data saved to 'layer_23_data.csv'

# %%
def get_bulk_data(base_url):
    import requests
    import pandas as pd
    from datetime import datetime


    # base_url = "https://services2.arcgis.com/mJaJSax0KPHoCNB6/ArcGIS/rest/services/DRPComplianceRelProd/FeatureServer/23/query"

    params = {
        "where": "1=1",  # Select all records
        "outFields": "*",  # Retrieve all fields
        "f": "json"  # Format response as JSON
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        # Parse JSON response
        data = response.json()
        
        # Extract features (attributes + geometry)
        features = data.get("features", [])
        
        # Process data
        records = []
        for feature in features:
            attributes = feature.get("attributes", {})  # Data fields
            # geometry = feature.get("geometry", {})  # Geographic coordinates
            records.append(attributes)
        df = pd.DataFrame(records)
        # df['Last_Update_On_Map'] = pd.to_datetime(df['Last_Update_On_Map'], unit='ms')
        return df
    else:
        print(f"Error: {response.status_code}")
        print("Response Text:", response.text)

# %%
i = 2
base_url = f"https://services2.arcgis.com/mJaJSax0KPHoCNB6/ArcGIS/rest/services/DRPComplianceRelProd/FeatureServer/{i}/query"
df = get_bulk_data(base_url=base_url)
display(df)
# Out:
#       OBJECTID         Substation   FeederID             Feeder_Name  \
# 0            1         LOS OSITOS  182082103         LOS OSITOS 2103
# 1            2            HIGHWAY  042651102            HIGHWAY 1102
# 2            3            LEMOORE  253601101            LEMOORE 1101
# 3            4              MENLO  024130403              MENLO 0403
# 4            5             PUEBLO  043291102             PUEBLO 1102
# ...        ...                ...        ...                     ...
# 1995      1996     CALIFORNIA AVE  252281110     CALIFORNIA AVE 1110
# 1996      1997          WELLFIELD  254291102          WELLFIELD 1102
# 1997      1998          TASSAJARA  014662106          TASSAJARA 2106
# 1998      1999  HUNTERS POINT (P)  022331104  HUNTERS POINT (P) 1104
# 1999      2000        SANTA MARIA  182671107        SANTA MARIA 1107
#
#      Nominal_Voltage Load_Profile_Redaction  ResCust  ComCust  IndCust  \
# 0               21kV                    Yes      539      116       14
# 1               12kV                     No      597      270      184
# 2               12kV                     No     2201      135       25
# 3             4.16kV                     No      972       41        3
# 4               12kV                    Yes     1868      247       57
# ...              ...                    ...      ...      ...      ...
# 1995            12kV                    Yes     1793      130       50
# 1996            12kV                    Yes       44       23        6
# 1997            21kV                     No     2775      123       17
# 1998            12kV                    Yes      286       36       16
# 1999            12kV                    Yes     2608      216       63
#
#       AgrCust  OthCust  Existing_DG  Queued_DG  Total_DG       Division  \
# 0         175        0         1180         10      1190  Central Coast
# 1           6       14         1400       2380      3780      North Bay
# 2         171        5         5190        210      5400         Fresno
# 3           0        4         1510        110      1620      Peninsula
# 4          22        6         1190         20      1210      North Bay
# ...       ...      ...          ...        ...       ...            ...
# 1995        0       13         5910         30      5940         Fresno
# 1996       94        6          810       3090      3900           Kern
# 1997        1        5         3530         90      3620         Diablo
# 1998        0        6           20          0        20  San Francisco
# 1999        3        8         1080         10      1090     Los Padres
#
#       VOLTNUM  Last_Update_On_Map  Publish  Shape__Length
# 0          21       1730914782000        1  214567.411148
# 1          12       1730914782000        1   65494.912644
# 2          12       1730914782000        1  115049.196746
# 3           4       1730914782000        1   18150.288981
# 4          12       1730914782000        1   41992.072790
# ...       ...                 ...      ...            ...
# 1995       12       1730914785000        1   25972.006771
# 1996       12       1730914785000        1   75056.935798
# 1997       21       1730914785000        1   72865.127460
# 1998       12       1730914785000        1   11565.514261
# 1999       12       1730914785000        1   36480.128053
#
# [2000 rows x 19 columns]

# %%
x = pd.read_csv('/Users/melek/Downloads/San Francisco/022010401.csv')
